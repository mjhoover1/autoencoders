# %%
import sklearn
import tensorflow as tf
from tensorflow import keras
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix

# %%
def plot_image(image):
    plt.imshow(image, cmap="binary")
    plt.axis("off")

# %%
nl = 1
abn = 8
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_train = x_train.astype(np.float32) / 255
x_test = x_test.astype(np.float32) / 255
normal_data = x_train[y_train == nl]
normal_labels = y_train[y_train == nl]
test_data = x_test[(y_test == abn) | (y_test == nl)]
test_labels = y_test[(y_test == abn) | (y_test == nl)]
test_labels_T_F = np.where(test_labels == nl, True, False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
normal_data.shape, test_data.shape, test_labels.shape
# Out:
# ((6742, 28, 28), (2109, 28, 28), (2109,))

# %%
normal_test_data = test_data[test_labels == nl]
abnormal_test_data = test_data[test_labels == abn]
normal_test_labels = test_labels[test_labels == nl]
abnormal_test_labels = test_labels[test_labels == abn]

# %%
normal_test_data.shape, abnormal_test_data.shape   #, normal_test_labels[0:20], abnormal_test_labels[0:20]
# Out:
# ((1135, 28, 28), (974, 28, 28))

# %%
def show_reconstructions(model, images=test_data, n_images=5):
    reconstructions = model.predict(images[:n_images])
    fig = plt.figure(figsize=(n_images * 1.5, 3))
    for image_index in range(n_images):
        plt.subplot(2, n_images, 1 + image_index)
        plot_image(images[image_index])
        plt.subplot(2, n_images, 1 + n_images + image_index)
        plot_image(reconstructions[image_index])

# %%
K = keras.backend
def rounded_accuracy(y_true, y_pred):
    return keras.metrics.binary_accuracy(tf.round(y_true), tf.round(y_pred))

# %%
class Sampling(keras.layers.Layer):
    def call(self, inputs):
        mean, log_var = inputs
        return K.random_normal(tf.shape(log_var)) * K.exp(log_var / 2) + mean

# %%
codings_size = 16

inputs = keras.layers.Input(shape=[28, 28])
z = keras.layers.Flatten()(inputs)
z = keras.layers.Dense(150, activation="selu")(z)
z = keras.layers.Dense(100, activation="selu")(z)
codings_mean = keras.layers.Dense(codings_size)(z)
codings_log_var = keras.layers.Dense(codings_size)(z)
codings = Sampling()([codings_mean, codings_log_var])
variational_encoder = keras.models.Model(
    inputs=[inputs], outputs=[codings_mean, codings_log_var, codings])

decoder_inputs = keras.layers.Input(shape=[codings_size])
x = keras.layers.Dense(100, activation="selu")(decoder_inputs)
x = keras.layers.Dense(150, activation="selu")(x)
x = keras.layers.Dense(28 * 28, activation="sigmoid")(x)
outputs = keras.layers.Reshape([28, 28])(x)
variational_decoder = keras.models.Model(inputs=[decoder_inputs], outputs=[outputs])

_, _, codings = variational_encoder(inputs)
reconstructions = variational_decoder(codings)
variational_ae = keras.models.Model(inputs=[inputs], outputs=[reconstructions])

latent_loss = -0.5 * K.sum(
    1 + codings_log_var - K.exp(codings_log_var) - K.square(codings_mean),
    axis=-1)
variational_ae.add_loss(K.mean(latent_loss) / 784.)
variational_ae.compile(loss="binary_crossentropy", optimizer="rmsprop", metrics=[rounded_accuracy])
history = variational_ae.fit(normal_data, normal_data, epochs=100, batch_size=512,
                             validation_data=(test_data, test_data), shuffle=True)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 10s 86ms/step - loss: 0.3340 - rounded_accuracy: 0.8652 - val_loss: 0.2587 - val_rounded_accuracy: 0.9004
# Epoch 2/100
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1484 - rounded_accuracy: 0.9515 - val_loss: 0.2470 - val_rounded_accuracy: 0.9034
# Epoch 3/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1249 - rounded_accuracy: 0.9585 - val_loss: 0.2496 - val_rounded_accuracy: 0.8960
# Epoch 4/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1133 - rounded_accuracy: 0.9611 - val_loss: 0.4402 - val_rounded_accuracy: 0.7925
# Epoch 5/100
# 14/14 [==============================] - 0s 22ms/step - loss: 0.1098 - rounded_accuracy: 0.9617 - val_loss: 0.2553 - val_rounded_accuracy: 0.8872
# Epoch 6/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.1015 - rounded_accuracy: 0.9651 - val_loss: 0.2855 - val_rounded_accuracy: 0.8758
# Epoch 7/100
# 14/14 [==============================] - 0s 21ms/step - loss: 0.1013 - rounded_accuracy: 0.9651 - val_loss: 0.2118 - val_rounded_accuracy: 0.9140
# Epoch 8/100
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0985 - rounded_accuracy: 0.9665 - val_loss: 0.2490 - val_rounded_accuracy: 0.8941
# Epoch 9/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0947 - rounded_accuracy: 0.9682 - val_loss: 0.2583 - val_rounded_accuracy: 0.9147
# Epoch 10/100
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0939 - rounded_accuracy: 0.9684 - val_loss: 0.2605 - val_rounded_accuracy: 0.9154
# Epoch 11/100
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0917 - rounded_accuracy: 0.9694 - val_loss: 0.2329 - val_rounded_accuracy: 0.9047
# Epoch 12/100
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0911 - rounded_accuracy: 0.9695 - val_loss: 0.2037 - val_rounded_accuracy: 0.9188
# Epoch 13/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0889 - rounded_accuracy: 0.9703 - val_loss: 0.1979 - val_rounded_accuracy: 0.9206
# Epoch 14/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0873 - rounded_accuracy: 0.9714 - val_loss: 0.2437 - val_rounded_accuracy: 0.9025
# Epoch 15/100
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0871 - rounded_accuracy: 0.9712 - val_loss: 0.2107 - val_rounded_accuracy: 0.9168
# Epoch 16/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0850 - rounded_accuracy: 0.9727 - val_loss: 0.2947 - val_rounded_accuracy: 0.8914
# Epoch 17/100
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0840 - rounded_accuracy: 0.9734 - val_loss: 0.1949 - val_rounded_accuracy: 0.9240
# Epoch 18/100
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0831 - rounded_accuracy: 0.9745 - val_loss: 0.1996 - val_rounded_accuracy: 0.9189
# Epoch 19/100
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0824 - rounded_accuracy: 0.9742 - val_loss: 0.2093 - val_rounded_accuracy: 0.9182
# Epoch 20/100
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0802 - rounded_accuracy: 0.9752 - val_loss: 0.3540 - val_rounded_accuracy: 0.8802
# Epoch 21/100
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0811 - rounded_accuracy: 0.9747 - val_loss: 0.2021 - val_rounded_accuracy: 0.9206
# Epoch 22/100
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0789 - rounded_accuracy: 0.9758 - val_loss: 0.3309 - val_rounded_accuracy: 0.8881
# Epoch 23/100
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0792 - rounded_accuracy: 0.9755 - val_loss: 0.1995 - val_rounded_accuracy: 0.9203
# Epoch 24/100
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0779 - rounded_accuracy: 0.9763 - val_loss: 0.2102 - val_rounded_accuracy: 0.9193
# Epoch 25/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0775 - rounded_accuracy: 0.9765 - val_loss: 0.1897 - val_rounded_accuracy: 0.9286
# Epoch 26/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0766 - rounded_accuracy: 0.9771 - val_loss: 0.1885 - val_rounded_accuracy: 0.9264
# Epoch 27/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0767 - rounded_accuracy: 0.9769 - val_loss: 0.2008 - val_rounded_accuracy: 0.9272
# Epoch 28/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0752 - rounded_accuracy: 0.9778 - val_loss: 0.3763 - val_rounded_accuracy: 0.8809
# Epoch 29/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0758 - rounded_accuracy: 0.9774 - val_loss: 0.2858 - val_rounded_accuracy: 0.8954
# Epoch 30/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0737 - rounded_accuracy: 0.9785 - val_loss: 0.2768 - val_rounded_accuracy: 0.9005
# Epoch 31/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0741 - rounded_accuracy: 0.9782 - val_loss: 0.2138 - val_rounded_accuracy: 0.9190
# Epoch 32/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0738 - rounded_accuracy: 0.9785 - val_loss: 0.1818 - val_rounded_accuracy: 0.9308
# Epoch 33/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0723 - rounded_accuracy: 0.9794 - val_loss: 0.1839 - val_rounded_accuracy: 0.9282
# Epoch 34/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0726 - rounded_accuracy: 0.9790 - val_loss: 0.1813 - val_rounded_accuracy: 0.9313
# Epoch 35/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0715 - rounded_accuracy: 0.9797 - val_loss: 0.2099 - val_rounded_accuracy: 0.9189
# Epoch 36/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0720 - rounded_accuracy: 0.9793 - val_loss: 0.4724 - val_rounded_accuracy: 0.8608
# Epoch 37/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0704 - rounded_accuracy: 0.9803 - val_loss: 0.1857 - val_rounded_accuracy: 0.9313
# Epoch 38/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0710 - rounded_accuracy: 0.9800 - val_loss: 0.2072 - val_rounded_accuracy: 0.9233
# Epoch 39/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0705 - rounded_accuracy: 0.9800 - val_loss: 0.2731 - val_rounded_accuracy: 0.9025
# Epoch 40/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0695 - rounded_accuracy: 0.9807 - val_loss: 0.1987 - val_rounded_accuracy: 0.9247
# Epoch 41/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0696 - rounded_accuracy: 0.9805 - val_loss: 0.2228 - val_rounded_accuracy: 0.9191
# Epoch 42/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0694 - rounded_accuracy: 0.9806 - val_loss: 0.2107 - val_rounded_accuracy: 0.9211
# Epoch 43/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0686 - rounded_accuracy: 0.9811 - val_loss: 0.2547 - val_rounded_accuracy: 0.9105
# Epoch 44/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0690 - rounded_accuracy: 0.9809 - val_loss: 0.2035 - val_rounded_accuracy: 0.9241
# Epoch 45/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0684 - rounded_accuracy: 0.9812 - val_loss: 0.2136 - val_rounded_accuracy: 0.9220
# Epoch 46/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0685 - rounded_accuracy: 0.9809 - val_loss: 0.2301 - val_rounded_accuracy: 0.9159
# Epoch 47/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0677 - rounded_accuracy: 0.9814 - val_loss: 0.2186 - val_rounded_accuracy: 0.9216
# Epoch 48/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0679 - rounded_accuracy: 0.9813 - val_loss: 0.1993 - val_rounded_accuracy: 0.9252
# Epoch 49/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0677 - rounded_accuracy: 0.9815 - val_loss: 0.1885 - val_rounded_accuracy: 0.9303
# Epoch 50/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0669 - rounded_accuracy: 0.9819 - val_loss: 0.2114 - val_rounded_accuracy: 0.9264
# Epoch 51/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0674 - rounded_accuracy: 0.9816 - val_loss: 0.2850 - val_rounded_accuracy: 0.9044
# Epoch 52/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0675 - rounded_accuracy: 0.9815 - val_loss: 0.1998 - val_rounded_accuracy: 0.9245
# Epoch 53/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0668 - rounded_accuracy: 0.9820 - val_loss: 0.2410 - val_rounded_accuracy: 0.9137
# Epoch 54/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0664 - rounded_accuracy: 0.9822 - val_loss: 0.2242 - val_rounded_accuracy: 0.9185
# Epoch 55/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0667 - rounded_accuracy: 0.9820 - val_loss: 0.2007 - val_rounded_accuracy: 0.9255
# Epoch 56/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0664 - rounded_accuracy: 0.9820 - val_loss: 0.2095 - val_rounded_accuracy: 0.9211
# Epoch 57/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0660 - rounded_accuracy: 0.9823 - val_loss: 0.2317 - val_rounded_accuracy: 0.9149
# Epoch 58/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0662 - rounded_accuracy: 0.9823 - val_loss: 0.2016 - val_rounded_accuracy: 0.9271
# Epoch 59/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0661 - rounded_accuracy: 0.9822 - val_loss: 0.2037 - val_rounded_accuracy: 0.9258
# Epoch 60/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0657 - rounded_accuracy: 0.9825 - val_loss: 0.2000 - val_rounded_accuracy: 0.9269
# Epoch 61/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0661 - rounded_accuracy: 0.9823 - val_loss: 0.1959 - val_rounded_accuracy: 0.9277
# Epoch 62/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0658 - rounded_accuracy: 0.9825 - val_loss: 0.1979 - val_rounded_accuracy: 0.9260
# Epoch 63/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0656 - rounded_accuracy: 0.9826 - val_loss: 0.2319 - val_rounded_accuracy: 0.9255
# Epoch 64/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0656 - rounded_accuracy: 0.9826 - val_loss: 0.1965 - val_rounded_accuracy: 0.9272
# Epoch 65/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0653 - rounded_accuracy: 0.9828 - val_loss: 0.2034 - val_rounded_accuracy: 0.9249
# Epoch 66/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0649 - rounded_accuracy: 0.9830 - val_loss: 0.1923 - val_rounded_accuracy: 0.9297
# Epoch 67/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0657 - rounded_accuracy: 0.9825 - val_loss: 0.2209 - val_rounded_accuracy: 0.9214
# Epoch 68/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0649 - rounded_accuracy: 0.9831 - val_loss: 0.2026 - val_rounded_accuracy: 0.9251
# Epoch 69/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0652 - rounded_accuracy: 0.9828 - val_loss: 0.1937 - val_rounded_accuracy: 0.9279
# Epoch 70/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0651 - rounded_accuracy: 0.9827 - val_loss: 0.1845 - val_rounded_accuracy: 0.9311
# Epoch 71/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0650 - rounded_accuracy: 0.9829 - val_loss: 0.1933 - val_rounded_accuracy: 0.9283
# Epoch 72/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0648 - rounded_accuracy: 0.9829 - val_loss: 0.1969 - val_rounded_accuracy: 0.9309
# Epoch 73/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0643 - rounded_accuracy: 0.9833 - val_loss: 0.1862 - val_rounded_accuracy: 0.9305
# Epoch 74/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0649 - rounded_accuracy: 0.9830 - val_loss: 0.1796 - val_rounded_accuracy: 0.9336
# Epoch 75/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0648 - rounded_accuracy: 0.9830 - val_loss: 0.1849 - val_rounded_accuracy: 0.9313
# Epoch 76/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0644 - rounded_accuracy: 0.9833 - val_loss: 0.2063 - val_rounded_accuracy: 0.9240
# Epoch 77/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0646 - rounded_accuracy: 0.9831 - val_loss: 0.1904 - val_rounded_accuracy: 0.9283
# Epoch 78/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0640 - rounded_accuracy: 0.9835 - val_loss: 0.2195 - val_rounded_accuracy: 0.9255
# Epoch 79/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0649 - rounded_accuracy: 0.9830 - val_loss: 0.1885 - val_rounded_accuracy: 0.9301
# Epoch 80/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0636 - rounded_accuracy: 0.9837 - val_loss: 0.1893 - val_rounded_accuracy: 0.9297
# Epoch 81/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0644 - rounded_accuracy: 0.9831 - val_loss: 0.1833 - val_rounded_accuracy: 0.9316
# Epoch 82/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0642 - rounded_accuracy: 0.9833 - val_loss: 0.2069 - val_rounded_accuracy: 0.9255
# Epoch 83/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0641 - rounded_accuracy: 0.9834 - val_loss: 0.2051 - val_rounded_accuracy: 0.9286
# Epoch 84/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0640 - rounded_accuracy: 0.9835 - val_loss: 0.1826 - val_rounded_accuracy: 0.9322
# Epoch 85/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0635 - rounded_accuracy: 0.9838 - val_loss: 0.2058 - val_rounded_accuracy: 0.9238
# Epoch 86/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0644 - rounded_accuracy: 0.9832 - val_loss: 0.1925 - val_rounded_accuracy: 0.9315
# Epoch 87/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0636 - rounded_accuracy: 0.9837 - val_loss: 0.1792 - val_rounded_accuracy: 0.9331
# Epoch 88/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0638 - rounded_accuracy: 0.9835 - val_loss: 0.1778 - val_rounded_accuracy: 0.9340
# Epoch 89/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0637 - rounded_accuracy: 0.9836 - val_loss: 0.1858 - val_rounded_accuracy: 0.9323
# Epoch 90/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0638 - rounded_accuracy: 0.9835 - val_loss: 0.1774 - val_rounded_accuracy: 0.9332
# Epoch 91/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0635 - rounded_accuracy: 0.9837 - val_loss: 0.1773 - val_rounded_accuracy: 0.9345
# Epoch 92/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0638 - rounded_accuracy: 0.9835 - val_loss: 0.1786 - val_rounded_accuracy: 0.9340
# Epoch 93/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0634 - rounded_accuracy: 0.9837 - val_loss: 0.2006 - val_rounded_accuracy: 0.9300
# Epoch 94/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0636 - rounded_accuracy: 0.9836 - val_loss: 0.1764 - val_rounded_accuracy: 0.9345
# Epoch 95/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0635 - rounded_accuracy: 0.9838 - val_loss: 0.1858 - val_rounded_accuracy: 0.9327
# Epoch 96/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0633 - rounded_accuracy: 0.9838 - val_loss: 0.1832 - val_rounded_accuracy: 0.9322
# Epoch 97/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0634 - rounded_accuracy: 0.9838 - val_loss: 0.1936 - val_rounded_accuracy: 0.9277
# Epoch 98/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0633 - rounded_accuracy: 0.9839 - val_loss: 0.1774 - val_rounded_accuracy: 0.9343
# Epoch 99/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0635 - rounded_accuracy: 0.9837 - val_loss: 0.1784 - val_rounded_accuracy: 0.9335
# Epoch 100/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0632 - rounded_accuracy: 0.9839 - val_loss: 0.1761 - val_rounded_accuracy: 0.9349

# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()

# %%
show_reconstructions(variational_ae, test_data, 30)
plt.show()

# %%
show_reconstructions(variational_ae, normal_test_data, 30)
plt.show()

# %%
show_reconstructions(variational_ae, abnormal_test_data, 30)
plt.show()

# %%
reconstructions_nl_test = variational_ae.predict(normal_test_data)

# %%
plt.figure(figsize=(25,7))
plt.plot(normal_test_data[0].ravel(), 'r')
plt.plot(reconstructions_nl_test[0].ravel(), 'g')
plt.fill_between(np.arange(28*28), reconstructions_nl_test[0].ravel(), normal_test_data[0].ravel(), color='blue')
plt.legend(labels=["Input", "Reconstruction", "Error"])
plt.show()

# %%
reconstructions_abn_test = variational_ae.predict(abnormal_test_data)

# %%
plt.figure(figsize=(1,1))
plt.imshow(abnormal_test_data[0], cmap="binary")
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(1,1))
plt.imshow(reconstructions_abn_test[0], cmap="binary")
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(25,7))
plt.plot(abnormal_test_data[0].ravel(), 'r')
plt.plot(reconstructions_abn_test[0].ravel(), 'g')
plt.fill_between(np.arange(28*28), reconstructions_abn_test[0].ravel(), normal_test_data[0].ravel(), color='blue')
plt.legend(labels=["Input", "Reconstruction", "Error"])
plt.show()

# %%
reconstructions_nl_data = variational_ae.predict(normal_data)
train_loss = tf.keras.losses.mae(reconstructions_nl_data.reshape(-1, 784), normal_data.reshape(-1, 784))
plt.hist(train_loss[None,:], bins=50)
plt.xlabel("Train loss")
plt.ylabel("No of examples")
plt.show()

# %%
threshold = np.mean(train_loss) + np.std(train_loss)
print("Threshold: ", threshold)
# Out:
# Threshold:  0.027255865

# %%
abn_test_loss = tf.keras.losses.mae(reconstructions_abn_test.reshape(-1,784), abnormal_test_data.reshape(-1,784))

plt.hist(abn_test_loss[None, :], bins=50)
plt.xlabel("Test loss")
plt.ylabel("No of examples")
plt.show()

# %%
def predict(model, data, threshold):
  reconstructions = model.predict(data)
  loss = tf.keras.losses.mae(reconstructions.reshape(-1, 784), data.reshape(-1, 784))
  return tf.math.less(loss, threshold)

def print_stats(predictions, labels):
  cf = confusion_matrix(labels, predictions)
  print("Confusion Matrix: \n prediction: F      T ")
  print("             {}   {}".format(preds[preds == False].shape[0], preds[preds == True].shape[0]))
  print(" label: F   [[{}   {}]    {}".format(cf[0,0], cf[0,1], test_labels_T_F[test_labels_T_F == False].shape[0]))
  print("        T    [{}   {}]]   {}".format(cf[1,0], cf[1,1], test_labels_T_F[test_labels_T_F == True].shape[0]))
  print("Accuracy = {}".format(accuracy_score(labels, predictions)))
  print("Precision = {}".format(precision_score(labels, predictions)))
  print("Recall = {}".format(recall_score(labels, predictions)))

# %%
preds = predict(variational_ae, test_data, threshold)
print_stats(preds, test_labels_T_F)
# Out:
# Confusion Matrix:
#  prediction: F      T
#              1060   1049
#  label: F   [[974   0]    974
#         T    [86   1049]]   1135
# Accuracy = 0.9592223802750118
# Precision = 1.0
# Recall = 0.9242290748898678

# %%
print(confusion_matrix(test_labels_T_F, preds))
# Out:
# [[ 974    0]
#  [  86 1049]]

# %%
reconstructions_test_data = variational_ae.predict(test_data)
test_loss = tf.keras.losses.mae(reconstructions_test_data.reshape(-1,784), test_data.reshape(-1,784))

plt.hist(test_loss[None, :], bins=50)
plt.xlabel("Test loss")
plt.ylabel("No of examples")
plt.show()

# %%
def plot_multiple_images(images, n_cols=None):
    n_cols = n_cols or len(images)
    n_rows = (len(images) - 1) // n_cols + 1
    if images.shape[-1] == 1:
        images = np.squeeze(images, axis=-1)
    plt.figure(figsize=(n_cols, n_rows))
    for index, image in enumerate(images):
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(image, cmap="binary")
        plt.axis("off")

# %%
codings = tf.random.normal(shape=[12, codings_size])
images = variational_decoder(codings).numpy()
plot_multiple_images(images, 4)
# save_fig("vae_generated_images_plot", tight_layout=False)

# %%
codings_grid = tf.reshape(codings, [1, 3, 4, codings_size])
larger_grid = tf.image.resize(codings_grid, size=[5, 7])
interpolated_codings = tf.reshape(larger_grid, [-1, codings_size])
images = variational_decoder(interpolated_codings).numpy()

plt.figure(figsize=(7, 5))
for index, image in enumerate(images):
    plt.subplot(5, 7, index + 1)
    if index%7%2==0 and index//7%2==0:
        plt.gca().get_xaxis().set_visible(False)
        plt.gca().get_yaxis().set_visible(False)
    else:
        plt.axis("off")
    plt.imshow(image, cmap="binary")
# save_fig("semantic_interpolation_plot", tight_layout=False)
