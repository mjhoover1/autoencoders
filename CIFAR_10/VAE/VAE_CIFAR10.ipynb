# %% [markdown]
# **References:** Chapter 17 of Geron's book. For 1-Dim plots, Keras tutorial : https://www.tensorflow.org/tutorials/generative/autoencoder
#
# This file trains a VAE with the instances of the normal digits in the training data.
#
# Then, it measures the reconstruction loss for the digits in the test data.
#
# The reconstruction loss for the instances of the abnormal digits in the test data is higher.
#
# A threshold is determined based on the distribution of the reconstruction losses of the normal training data (threshold = mean + 2.5*std of this distribution).
#
# Then, if the reconstruction loss of a digit in the test data is higher than this threshold, it is classified as abnormal.
#
# By comparing with the known labels of test data (with T for normal digit(s) and F for abnormal digit(s)), the confusion matrix and the accuracy is calculated.

# %%
import sklearn
import tensorflow as tf
from tensorflow import keras
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix

# %%
def plot_image(image):
    plt.imshow(image, cmap="binary")
    plt.axis("off")

# %% [markdown]
# **Loading the MNIST data and forming arrays of the normal training data and the test data (normal and abnormal)**

# %%
nl1 = 3   # cat
nl2 = 3
abn1 = 8  # ship
abn2 = 8

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

x_train = x_train.astype(np.float32) / 255
x_test = x_test.astype(np.float32) / 255

normal_data = x_train[(y_train == nl1).flatten() | (y_train == nl2).flatten()]    # Normal training data (cats)
normal_labels = y_train[(y_train == nl1).flatten() | (y_train == nl2).flatten()]

test_data = x_test[(y_test == abn1).flatten() | (y_test == abn2).flatten() | (y_test == nl1).flatten() | (y_test == nl2).flatten()]   # Test data (ships)
test_labels = y_test[(y_test == abn1).flatten() | (y_test == abn2).flatten() | (y_test == nl1).flatten() | (y_test == nl2).flatten()]

test_labels_T_F = np.where((test_labels == nl1).flatten() | (test_labels == nl2).flatten(), True, False) 
# Array of T and F, T where test classes are normal and F where test classes are abnormal

normal_data = x_train[(y_train == nl1).flatten() | (y_train == nl2).flatten()]    # Normal training data (cats)
normal_labels = y_train[(y_train == nl1).flatten() | (y_train == nl2).flatten()]

test_data = x_test[((y_test == abn1) | (y_test == abn2) | (y_test == nl1) | (y_test == nl2)).flatten()]   # Test data (ships)
test_labels = y_test[((y_test == abn1) | (y_test == abn2) | (y_test == nl1) | (y_test == nl2)).flatten()]

test_labels_T_F = np.where((test_labels == nl1).flatten() | (test_labels == nl2).flatten(), True, False) 
# Array of T and F, T where test classes are normal and F where test classes are abnormal

# %%
normal_data.shape, test_data.shape, test_labels.shape
# Out:
# ((5000, 32, 32, 3), (2000, 32, 32, 3), (2000, 1))

# %%
normal_test_data = test_data[(test_labels == nl1).flatten() | (test_labels == nl2).flatten()]            # The normal digits in the test data
abnormal_test_data = test_data[(test_labels == abn1).flatten() | (test_labels == abn2).flatten()]        # The abnormal digits in the test data
normal_test_labels = test_labels[(test_labels == nl1).flatten() | (test_labels == nl2).flatten()]        # Their labels
abnormal_test_labels = test_labels[(test_labels == abn1).flatten() | (test_labels == abn2).flatten()]    # Their labels

# %%
normal_test_data.shape, abnormal_test_data.shape
# Out:
# ((1000, 32, 32, 3), (1000, 32, 32, 3))

# %%
def show_reconstructions(model, images=test_data, n_images=5):
    reconstructions = model.predict(images[:n_images])
    fig = plt.figure(figsize=(n_images * 1.5, 3))
    for image_index in range(n_images):
        plt.subplot(2, n_images, 1 + image_index)
        plot_image(images[image_index])
        plt.subplot(2, n_images, 1 + n_images + image_index)
        plot_image(reconstructions[image_index])

# %%
K = keras.backend
# def rounded_accuracy(y_true, y_pred):
  #  return keras.metrics.binary_accuracy(tf.round(y_true), tf.round(y_pred))

# %%
# For details please see Geron's book. Uses the reparametrization trick to do stochastic 
# sampling from the MVN distribution, while allowing the 2 parallel layers containing the 
# means and stds of the MVN distribution for each dimension to be trained via 
# backpropogation of the error signal.
class Sampling(keras.layers.Layer):
    def call(self, inputs):
        mean, log_var = inputs
        return K.random_normal(tf.shape(log_var)) * K.exp(log_var / 2) + mean

# %%
# For details please see Geron's book. 
codings_size = 32   # The number of dimensions of the MVN distribution in the sampling layer

inputs = keras.layers.Input(shape=[32, 32, 3])
z = keras.layers.Flatten()(inputs)
z = keras.layers.Dense(128, activation="selu")(z)
z = keras.layers.Dense(64, activation="selu")(z)

# Parallel layers at the end of the encoder for means 
# and standard deviations of the Multivariate Normal (MVN) distribution 
# in the dimensions of the coding size (here 32). 
codings_mean = keras.layers.Dense(codings_size)(z)
codings_log_var = keras.layers.Dense(codings_size)(z)

# Sampling layer at the end of the encoder
codings = Sampling()([codings_mean, codings_log_var])
variational_encoder = keras.models.Model(
    inputs=[inputs], outputs=[codings_mean, codings_log_var, codings])

decoder_inputs = keras.layers.Input(shape=[codings_size])
x = keras.layers.Dense(64, activation="selu")(decoder_inputs)
x = keras.layers.Dense(128, activation="selu")(x)
x = keras.layers.Dense(32 * 32 * 3, activation="sigmoid")(x)
outputs = keras.layers.Reshape([32, 32, 3])(x)
variational_decoder = keras.models.Model(inputs=[decoder_inputs], outputs=[outputs])

_, _, codings = variational_encoder(inputs)
reconstructions = variational_decoder(codings)
variational_ae = keras.models.Model(inputs=[inputs], outputs=[reconstructions])

# The latent loss function
latent_loss = -0.5 * K.sum(
    1 + codings_log_var - K.exp(codings_log_var) - K.square(codings_mean),
    axis=-1)

# Add the latent loss to the reconstruction loss
variational_ae.add_loss(K.mean(latent_loss) / 32. / 32 / 3)

# %%
 # For the reconstruction loss binary cross-entropy loss is used. 
# For details please see Chapter 17 of Geron's book (Stacked AE and VAE sections) 
variational_ae.compile(loss="binary_crossentropy", optimizer="rmsprop")
history = variational_ae.fit(normal_data, normal_data, epochs=100, batch_size=512,
                             validation_data=(test_data, test_data), shuffle=True)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 6s 64ms/step - loss: 91.1663 - val_loss: 1.8065
# Epoch 2/100
# 10/10 [==============================] - 0s 30ms/step - loss: 1.3272 - val_loss: 1.1781
# Epoch 3/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.9933 - val_loss: 0.9502
# Epoch 4/100
# 10/10 [==============================] - 0s 29ms/step - loss: 0.8482 - val_loss: 0.8444
# Epoch 5/100
# 10/10 [==============================] - 0s 31ms/step - loss: 0.7663 - val_loss: 0.7571
# Epoch 6/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.7155 - val_loss: 0.7117
# Epoch 7/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6857 - val_loss: 0.6909
# Epoch 8/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.6710 - val_loss: 0.6769
# Epoch 9/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.6597 - val_loss: 0.6661
# Epoch 10/100
# 10/10 [==============================] - 0s 29ms/step - loss: 0.6532 - val_loss: 0.6522
# Epoch 11/100
# 10/10 [==============================] - 0s 29ms/step - loss: 0.6485 - val_loss: 0.6483
# Epoch 12/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.6470 - val_loss: 0.6544
# Epoch 13/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6404 - val_loss: 0.6478
# Epoch 14/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6447 - val_loss: 0.6448
# Epoch 15/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.6398 - val_loss: 0.6773
# Epoch 16/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6546 - val_loss: 0.6588
# Epoch 17/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.6432 - val_loss: 0.6430
# Epoch 18/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6644 - val_loss: 0.6702
# Epoch 19/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6478 - val_loss: 0.6647
# Epoch 20/100
# 10/10 [==============================] - 0s 30ms/step - loss: 0.6626 - val_loss: 0.6877
# Epoch 21/100
# 10/10 [==============================] - 0s 29ms/step - loss: 0.6518 - val_loss: 0.6705
# Epoch 22/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.6549 - val_loss: 0.6798
# Epoch 23/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6607 - val_loss: 0.6403
# Epoch 24/100
# 10/10 [==============================] - 0s 29ms/step - loss: 0.6493 - val_loss: 0.6839
# Epoch 25/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6509 - val_loss: 0.6646
# Epoch 26/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6501 - val_loss: 0.6491
# Epoch 27/100
# 10/10 [==============================] - 0s 31ms/step - loss: 0.6466 - val_loss: 0.6669
# Epoch 28/100
# 10/10 [==============================] - 0s 29ms/step - loss: 0.6434 - val_loss: 0.6596
# Epoch 29/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6475 - val_loss: 0.6738
# Epoch 30/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6391 - val_loss: 0.6484
# Epoch 31/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6407 - val_loss: 0.6680
# Epoch 32/100
# 10/10 [==============================] - 0s 30ms/step - loss: 0.6423 - val_loss: 0.6487
# Epoch 33/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.6399 - val_loss: 0.6411
# Epoch 34/100
# 10/10 [==============================] - 0s 29ms/step - loss: 0.6322 - val_loss: 0.6549
# Epoch 35/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.6391 - val_loss: 0.6410
# Epoch 36/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6338 - val_loss: 0.6477
# Epoch 37/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.6355 - val_loss: 0.6367
# Epoch 38/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6379 - val_loss: 0.6346
# Epoch 39/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.6305 - val_loss: 0.6437
# Epoch 40/100
# 10/10 [==============================] - 0s 29ms/step - loss: 0.6320 - val_loss: 0.6388
# Epoch 41/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6290 - val_loss: 0.6439
# Epoch 42/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.6372 - val_loss: 0.6387
# Epoch 43/100
# 10/10 [==============================] - 0s 30ms/step - loss: 0.6252 - val_loss: 0.6319
# Epoch 44/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6308 - val_loss: 0.6405
# Epoch 45/100
# 10/10 [==============================] - 0s 29ms/step - loss: 0.6240 - val_loss: 0.6402
# Epoch 46/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6370 - val_loss: 0.6290
# Epoch 47/100
# 10/10 [==============================] - 0s 30ms/step - loss: 0.6240 - val_loss: 0.6316
# Epoch 48/100
# 10/10 [==============================] - 0s 29ms/step - loss: 0.6261 - val_loss: 0.6291
# Epoch 49/100
# 10/10 [==============================] - 0s 29ms/step - loss: 0.6236 - val_loss: 0.6532
# Epoch 50/100
# 10/10 [==============================] - 0s 30ms/step - loss: 0.6302 - val_loss: 0.6396
# Epoch 51/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6231 - val_loss: 0.6397
# Epoch 52/100
# 10/10 [==============================] - 0s 29ms/step - loss: 0.6272 - val_loss: 0.6324
# Epoch 53/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.6224 - val_loss: 0.6301
# Epoch 54/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.6263 - val_loss: 0.6267
# Epoch 55/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6181 - val_loss: 0.6294
# Epoch 56/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6251 - val_loss: 0.6349
# Epoch 57/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6235 - val_loss: 0.6229
# Epoch 58/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.6199 - val_loss: 0.6505
# Epoch 59/100
# 10/10 [==============================] - 0s 29ms/step - loss: 0.6221 - val_loss: 0.6340
# Epoch 60/100
# 10/10 [==============================] - 0s 29ms/step - loss: 0.6221 - val_loss: 0.6240
# Epoch 61/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.6215 - val_loss: 0.6264
# Epoch 62/100
# 10/10 [==============================] - 0s 30ms/step - loss: 0.6211 - val_loss: 0.6279
# Epoch 63/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6197 - val_loss: 0.6218
# Epoch 64/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6164 - val_loss: 0.6364
# Epoch 65/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6235 - val_loss: 0.6257
# Epoch 66/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6173 - val_loss: 0.6310
# Epoch 67/100
# 10/10 [==============================] - 0s 29ms/step - loss: 0.6211 - val_loss: 0.6206
# Epoch 68/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6149 - val_loss: 0.6247
# Epoch 69/100
# 10/10 [==============================] - 0s 30ms/step - loss: 0.6219 - val_loss: 0.6266
# Epoch 70/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6178 - val_loss: 0.6257
# Epoch 71/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6167 - val_loss: 0.6209
# Epoch 72/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.6195 - val_loss: 0.6213
# Epoch 73/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6159 - val_loss: 0.6218
# Epoch 74/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.6176 - val_loss: 0.6278
# Epoch 75/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.6169 - val_loss: 0.6228
# Epoch 76/100
# 10/10 [==============================] - 0s 29ms/step - loss: 0.6155 - val_loss: 0.6300
# Epoch 77/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6163 - val_loss: 0.6178
# Epoch 78/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6135 - val_loss: 0.6222
# Epoch 79/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6174 - val_loss: 0.6405
# Epoch 80/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6186 - val_loss: 0.6166
# Epoch 81/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6111 - val_loss: 0.6242
# Epoch 82/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.6215 - val_loss: 0.6231
# Epoch 83/100
# 10/10 [==============================] - 0s 30ms/step - loss: 0.6104 - val_loss: 0.6190
# Epoch 84/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6137 - val_loss: 0.6234
# Epoch 85/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6170 - val_loss: 0.6282
# Epoch 86/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6133 - val_loss: 0.6199
# Epoch 87/100
# 10/10 [==============================] - 0s 29ms/step - loss: 0.6150 - val_loss: 0.6222
# Epoch 88/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6124 - val_loss: 0.6237
# Epoch 89/100
# 10/10 [==============================] - 0s 30ms/step - loss: 0.6137 - val_loss: 0.6317
# Epoch 90/100
# 10/10 [==============================] - 0s 30ms/step - loss: 0.6141 - val_loss: 0.6150
# Epoch 91/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6133 - val_loss: 0.6233
# Epoch 92/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6131 - val_loss: 0.6222
# Epoch 93/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6125 - val_loss: 0.6181
# Epoch 94/100
# 10/10 [==============================] - 0s 30ms/step - loss: 0.6141 - val_loss: 0.6203
# Epoch 95/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6108 - val_loss: 0.6220
# Epoch 96/100
# 10/10 [==============================] - 0s 30ms/step - loss: 0.6144 - val_loss: 0.6147
# Epoch 97/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.6105 - val_loss: 0.6230
# Epoch 98/100
# 10/10 [==============================] - 0s 29ms/step - loss: 0.6134 - val_loss: 0.6192
# Epoch 99/100
# 10/10 [==============================] - 0s 29ms/step - loss: 0.6095 - val_loss: 0.6196
# Epoch 100/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.6135 - val_loss: 0.6205

# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()

# %%
show_reconstructions(variational_ae, test_data, 30)
plt.show()

# %%
show_reconstructions(variational_ae, normal_test_data, 30)
plt.show()

# %%
show_reconstructions(variational_ae, abnormal_test_data, 30)
plt.show()

# %%
reconstructions_nl_test = variational_ae.predict(normal_test_data)

# %%
plt.figure(figsize=(25,7))
plt.plot(normal_test_data[0].ravel(), 'r')
plt.plot(reconstructions_nl_test[0].ravel(), 'g')
plt.fill_between(np.arange(32*32*3), reconstructions_nl_test[0].ravel(), normal_test_data[0].ravel(), color='blue')
plt.legend(labels=["Input", "Reconstruction", "Error"])
plt.show()

# %%
reconstructions_abn_test = variational_ae.predict(abnormal_test_data)

# %%
plt.figure(figsize=(1,1))
plt.imshow(abnormal_test_data[0], cmap="binary")
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(1,1))
plt.imshow(reconstructions_abn_test[0], cmap="binary")
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(25,7))
plt.plot(abnormal_test_data[0].ravel(), 'r')
plt.plot(reconstructions_abn_test[0].ravel(), 'g')
plt.fill_between(np.arange(32*32*3), reconstructions_abn_test[0].ravel(), normal_test_data[0].ravel(), color='blue')
plt.legend(labels=["Input", "Reconstruction", "Error"])
plt.show()

# %% [markdown]
# **Distribution of the reconstruction losses of the normal training data**

# %%
reconstructions_nl_data = variational_ae.predict(normal_data)
train_loss = tf.keras.losses.mae(reconstructions_nl_data.reshape(-1, 32*32*3), normal_data.reshape(-1, 32*32*3))
plt.hist(train_loss[None,:], bins=50)
plt.xlabel("Train loss")
plt.ylabel("No of examples")
plt.show()

# %%
print("Mean: ", np.mean(train_loss))
print("Std: ", np.std(train_loss))
# Out:
# Mean:  0.1253783
# Std:  0.0271035

# %%
threshold1 = np.mean(train_loss) + 2.5*np.std(train_loss)
print("Threshold1: ", threshold1)
# Out:
# Threshold1:  0.19313704688102007

# %% [markdown]
# **Distribution of the reconstruction losses of the abnormal test data**

# %%
abn_test_loss = tf.keras.losses.mae(reconstructions_abn_test.reshape(-1,32*32*3), abnormal_test_data.reshape(-1,32*32*3))

plt.hist(abn_test_loss[None, :], bins=50)
plt.xlabel("Test loss")
plt.ylabel("No of examples")
plt.show()

# %%
# threshold2 = np.mean(abn_test_loss) - np.std(abn_test_loss)
# print("Threshold2: ", threshold2)

# %%
np.mean(abn_test_loss) , np.std(abn_test_loss)
# Out:
# (0.122395456, 0.024610113)

# %% [markdown]
# **Threshold will be threshold1 = mean + std of the distribution of the reconstruction losses of the normal training data**

# %%
threshold = threshold1

# %% [markdown]
# **Calculation of the confusion matrix**

# %%
def predict(model, data, threshold):
  reconstructions = model.predict(data)
  loss = tf.keras.losses.mae(reconstructions.reshape(-1, 32*32*3), data.reshape(-1, 32*32*3))
  return tf.math.less(loss, threshold)

def print_stats(predictions, labels):
  cf = confusion_matrix(labels, predictions)
  print("Confusion Matrix: \n prediction: F      T ")
  print("             {}   {}".format(preds[preds == False].shape[0], preds[preds == True].shape[0]))
  print(" label: F   [[{}   {}]    {}".format(cf[0,0], cf[0,1], test_labels_T_F[test_labels_T_F == False].shape[0]))
  print("        T    [{}   {}]]   {}".format(cf[1,0], cf[1,1], test_labels_T_F[test_labels_T_F == True].shape[0]))
  print("Accuracy = {}".format(accuracy_score(labels, predictions)))
  print("Precision = {}".format(precision_score(labels, predictions)))
  print("Recall = {}".format(recall_score(labels, predictions)))

# %%
preds = predict(variational_ae, test_data, threshold)
print_stats(preds, test_labels_T_F)
# Out:
# Confusion Matrix:
#  prediction: F      T
#              22   1978
#  label: F   [[5   995]    1000
#         T    [17   983]]   1000
# Accuracy = 0.494
# Precision = 0.4969666329625885
# Recall = 0.983

# %%
print(confusion_matrix(test_labels_T_F, preds))
# Out:
# [[  5 995]
#  [ 17 983]]

# %% [markdown]
# **Distribution of the reconstruction losses of the test data (normal and abnormal)**

# %%
reconstructions_test_data = variational_ae.predict(test_data)
test_loss = tf.keras.losses.mae(reconstructions_test_data.reshape(-1,32*32*3), test_data.reshape(-1,32*32*3))

plt.hist(test_loss[None, :], bins=50)
plt.xlabel("Test loss")
plt.ylabel("No of examples")
plt.show()

# %%
def plot_multiple_images(images, n_cols=None):
    n_cols = n_cols or len(images)
    n_rows = (len(images) - 1) // n_cols + 1
    if images.shape[-1] == 1:
        images = np.squeeze(images, axis=-1)
    plt.figure(figsize=(n_cols, n_rows))
    for index, image in enumerate(images):
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(image, cmap="binary")
        plt.axis("off")

# %% [markdown]
# **Extra Info**
#
# Giving the VAE codings (please see book) (Just informative, not the goal here)

# %%
codings = tf.random.normal(shape=[12, codings_size])
images = variational_decoder(codings).numpy()
plot_multiple_images(images, 4)
# save_fig("vae_generated_images_plot", tight_layout=False)

# %%
codings_grid = tf.reshape(codings, [1, 3, 4, codings_size])
larger_grid = tf.image.resize(codings_grid, size=[5, 7])
interpolated_codings = tf.reshape(larger_grid, [-1, codings_size])
images = variational_decoder(interpolated_codings).numpy()

plt.figure(figsize=(7, 5))
for index, image in enumerate(images):
    plt.subplot(5, 7, index + 1)
    if index%7%2==0 and index//7%2==0:
        plt.gca().get_xaxis().set_visible(False)
        plt.gca().get_yaxis().set_visible(False)
    else:
        plt.axis("off")
    plt.imshow(image, cmap="binary")
# save_fig("semantic_interpolation_plot", tight_layout=False)
