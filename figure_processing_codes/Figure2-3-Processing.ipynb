# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !ls gdrive/MyDrive
# Out:
# 'Colab Notebooks'   Figure1-Processing.ipynb   Files1
#  CSV		    Figure2.csv
#  Figure1.csv	    Figure2-Processing.ipynb

# %%
df = pd.read_csv("/content/gdrive/MyDrive/Figure2.csv")
df.dtypes
# Out:
# Experiment     object
# AE            float64
# VAE           float64
# VAE b=0       float64
# mVAE b=0.5    float64
# mVAE b=16     float64
# dtype: object

# %%
df
# Out:
#   Experiment      AE     VAE  VAE b=0  mVAE b=0.5  mVAE b=16
# 0   0 A; r N  0.0330  0.0400   0.0300      0.0350     0.0910
# 1   1 A; r N  0.0340  0.0430   0.0330      0.0360     0.0980
# 2   2 A; r N  0.0327  0.0399   0.0281      0.0324     0.0894
# 3   3 A; r N  0.0322  0.0397   0.0292      0.0328     0.0888
# 4   4 A; r N  0.0314  0.0401   0.0291      0.0333     0.0896
# 5   5 A; r N  0.0308  0.0391   0.0301      0.0332     0.0882
# 6   6 A; r N  0.0320  0.0412   0.0302      0.0340     0.0920
# 7   7 A; r N  0.0328  0.0403   0.0310      0.0339     0.0913
# 8   8 A; r N  0.0304  0.0382   0.0283      0.0322     0.0903
# 9   9 A; r N  0.0345  0.0414   0.0318      0.0354     0.0929

# %%
# df.loc[:, 'AE':] *= 100

# %%
import numpy as np
import matplotlib.pyplot as plt
ax = df.plot(x='Experiment', kind='bar', width=0.8, figsize=(8, 4), fontsize=12, color=['b', 'c', 'magenta', 'lightgreen', 'orange',])
ax.grid(axis="y", linestyle=':')
ax.set_ylabel('mean MAE reconstruction loss \n of normal test data', fontsize = 12)
ax.set_ylim(0, 0.1)
ax.set_xlabel('Experiments', fontsize = 12)
list2 = list(df.Experiment)
ax.set_xticklabels(list2, rotation=55, ha='right')
ax.legend(bbox_to_anchor=(1, 1.0), fontsize = 10)
plt.show()

# %%
df3 = pd.read_csv("/content/gdrive/MyDrive/Figure3.csv")
df3.dtypes
# Out:
# Experiment     object
# AE            float64
# VAE           float64
# VAE b=0       float64
# mVAE b=0.5    float64
# mVAE b=16     float64
# dtype: object

# %%
df3
# Out:
#   Experiment      AE     VAE  VAE b=0  mVAE b=0.5  mVAE b=16
# 0   0 A; r N  0.0660  0.0710   0.0560      0.0690     0.1460
# 1   1 A; r N  0.0227  0.0312   0.0224      0.0259     0.0903
# 2   2 A; r N  0.0713  0.0783   0.0618      0.0682     0.1445
# 3   3 A; r N  0.0594  0.0642   0.0525      0.0557     0.1218
# 4   4 A; r N  0.0567  0.0626   0.0502      0.0536     0.1085
# 5   5 A; r N  0.0601  0.0662   0.0587      0.0590     0.1226
# 6   6 A; r N  0.0604  0.0674   0.0540      0.0613     0.1434
# 7   7 A; r N  0.0418  0.0464   0.0362      0.0420     0.1057
# 8   8 A; r N  0.0579  0.0652   0.0544      0.0604     0.1238
# 9   9 A; r N  0.0388  0.0463   0.0353      0.0382     0.1032

# %%
import numpy as np
import matplotlib.pyplot as plt
ax = df.plot(x='Experiment', kind='bar', width=0.8, figsize=(8, 4), fontsize=12, color=['b', 'c', 'magenta', 'lightgreen', 'orange',])
ax.grid(axis="y", linestyle=':')
ax.set_ylabel('mean MAE reconstruction loss \n of abnormal test data', fontsize = 12)
ax.set_ylim(0, 0.1)
ax.set_xlabel('Experiments \n Abnormal test data', fontsize = 12)
list2 = list(df.Experiment)
ax.set_xticklabels(list2, rotation=55, ha='right')
ax.legend(bbox_to_anchor=(1, 1.0), fontsize = 10)
plt.show()
