# %%
import sklearn
import tensorflow as tf
from tensorflow import keras
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix

# %%
def plot_image(image):
    plt.imshow(image, cmap="binary")
    plt.axis("off")

# %%
nl1 = 4
nl2 = 4
abn1 = 8
abn2 = 8
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_train = x_train.astype(np.float32) / 255
x_test = x_test.astype(np.float32) / 255
normal_data = x_train[(y_train == nl1) | (y_train == nl2)]
normal_labels = y_train[(y_train == nl1) | (y_train == nl2)]
test_data = x_test[(y_test == abn1) | (y_test == abn2) | (y_test == nl1) | (y_test == nl2)]
test_labels = y_test[(y_test == abn1) | (y_test == abn2) | (y_test == nl1) | (y_test == nl2)]
test_labels_T_F = np.where((test_labels == nl1) | (test_labels == nl2), True, False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
normal_data.shape, test_data.shape, test_labels.shape
# Out:
# ((5842, 28, 28), (1956, 28, 28), (1956,))

# %%
normal_test_data = test_data[(test_labels == nl1) | (test_labels == nl2)]
abnormal_test_data = test_data[(test_labels == abn1) | (test_labels == abn2)]
normal_test_labels = test_labels[(test_labels == nl1) | (test_labels == nl2)]
abnormal_test_labels = test_labels[(test_labels == abn1) | (test_labels == abn2)]

# %%
normal_test_data.shape, abnormal_test_data.shape   #, normal_test_labels[0:20], abnormal_test_labels[0:20]
# Out:
# ((982, 28, 28), (974, 28, 28))

# %%
def show_reconstructions(model, images=test_data, n_images=5):
    reconstructions = model.predict(images[:n_images])
    fig = plt.figure(figsize=(n_images * 1.5, 3))
    for image_index in range(n_images):
        plt.subplot(2, n_images, 1 + image_index)
        plot_image(images[image_index])
        plt.subplot(2, n_images, 1 + n_images + image_index)
        plot_image(reconstructions[image_index])

# %%
K = keras.backend
def rounded_accuracy(y_true, y_pred):
    return keras.metrics.binary_accuracy(tf.round(y_true), tf.round(y_pred))

# %%
class Sampling(keras.layers.Layer):
    def call(self, inputs):
        mean_1, log_var_1, mean_2, log_var_2, ratio = inputs
        return (K.random_normal(tf.shape(log_var_1)) * K.exp(log_var_1 / 2) + mean_1) + (K.random_normal(tf.shape(log_var_2)) * K.exp(log_var_2 / 2) + mean_2)*ratio

# %%
codings_size = 10

inputs = keras.layers.Input(shape=[28, 28])
z = keras.layers.Flatten()(inputs)
z = keras.layers.Dense(128, activation="selu")(z)
z = keras.layers.Dense(64, activation="selu")(z)
codings_mean_1 = keras.layers.Dense(codings_size)(z)
codings_log_var_1 = keras.layers.Dense(codings_size)(z)
codings_mean_2 = keras.layers.Dense(codings_size)(z)
codings_log_var_2 = keras.layers.Dense(codings_size)(z)
codings_ratio = keras.layers.Dense(codings_size)(z)
codings = Sampling()([codings_mean_1, codings_log_var_1, codings_mean_2, codings_log_var_2, codings_ratio])
variational_encoder = keras.models.Model(
    inputs=[inputs], outputs=[codings_mean_1, codings_log_var_1, codings_mean_2, codings_log_var_2, codings_ratio, codings])

decoder_inputs = keras.layers.Input(shape=[codings_size])
x = keras.layers.Dense(64, activation="selu")(decoder_inputs)
x = keras.layers.Dense(128, activation="selu")(x)
x = keras.layers.Dense(28 * 28, activation="sigmoid")(x)
outputs = keras.layers.Reshape([28, 28])(x)
variational_decoder = keras.models.Model(inputs=[decoder_inputs], outputs=[outputs])

_, _, _, _, _, codings = variational_encoder(inputs)
reconstructions = variational_decoder(codings)
variational_ae = keras.models.Model(inputs=[inputs], outputs=[reconstructions])

array1 = codings_log_var_1 - K.exp(codings_log_var_1) - K.square(codings_mean_1)
array2 = (codings_log_var_2 - K.exp(codings_log_var_2) - K.square(codings_mean_2)) # *  codings_ratio
sum1 = K.sum(1 + array1, axis=-1)
sum2 = K.sum(1 + array2, axis=-1)
print(sum1.shape)  
latent_loss = -0.5 * tf.math.maximum(sum1, sum2)
# latent_loss = -0.5 * K.sum(1 + (array1 + array2)/(1 + codings_ratio/codings_ratio), axis=-1) 
variational_ae.add_loss(K.mean(latent_loss) / 784.)
variational_ae.compile(loss="binary_crossentropy", optimizer="rmsprop")
history = variational_ae.fit(normal_data, normal_data, epochs=100, batch_size=512,
                             validation_data=(test_data, test_data), shuffle=True)
# Out:
# (None,)
# Epoch 1/100
# 12/12 [==============================] - 11s 89ms/step - loss: 0.4187 - val_loss: 0.2770
# Epoch 2/100
# 12/12 [==============================] - 0s 20ms/step - loss: 0.2267 - val_loss: 0.2672
# Epoch 3/100
# 12/12 [==============================] - 0s 26ms/step - loss: 0.2180 - val_loss: 0.2660
# Epoch 4/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.2073 - val_loss: 0.2443
# Epoch 5/100
# 12/12 [==============================] - 0s 33ms/step - loss: 0.1925 - val_loss: 0.2513
# Epoch 6/100
# 12/12 [==============================] - 0s 22ms/step - loss: 0.1828 - val_loss: 0.2336
# Epoch 7/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.1737 - val_loss: 0.2354
# Epoch 8/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.1668 - val_loss: 0.2325
# Epoch 9/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.1632 - val_loss: 0.2330
# Epoch 10/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.1581 - val_loss: 0.2384
# Epoch 11/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.1568 - val_loss: 0.2296
# Epoch 12/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.1526 - val_loss: 0.2292
# Epoch 13/100
# 12/12 [==============================] - 0s 27ms/step - loss: 0.1502 - val_loss: 0.2343
# Epoch 14/100
# 12/12 [==============================] - 0s 26ms/step - loss: 0.1477 - val_loss: 0.2321
# Epoch 15/100
# 12/12 [==============================] - 0s 22ms/step - loss: 0.1442 - val_loss: 0.2356
# Epoch 16/100
# 12/12 [==============================] - 0s 28ms/step - loss: 0.1432 - val_loss: 0.2313
# Epoch 17/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.1407 - val_loss: 0.2247
# Epoch 18/100
# 12/12 [==============================] - 0s 27ms/step - loss: 0.1376 - val_loss: 0.2250
# Epoch 19/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.1367 - val_loss: 0.2239
# Epoch 20/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.1360 - val_loss: 0.2245
# Epoch 21/100
# 12/12 [==============================] - 0s 22ms/step - loss: 0.1344 - val_loss: 0.2232
# Epoch 22/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.1319 - val_loss: 0.2224
# Epoch 23/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.1313 - val_loss: 0.2211
# Epoch 24/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.1299 - val_loss: 0.2230
# Epoch 25/100
# 12/12 [==============================] - 0s 19ms/step - loss: 0.1298 - val_loss: 0.2173
# Epoch 26/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.1285 - val_loss: 0.2211
# Epoch 27/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.1273 - val_loss: 0.2180
# Epoch 28/100
# 12/12 [==============================] - 0s 26ms/step - loss: 0.1265 - val_loss: 0.2188
# Epoch 29/100
# 12/12 [==============================] - 0s 17ms/step - loss: 0.1257 - val_loss: 0.2175
# Epoch 30/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1248 - val_loss: 0.2202
# Epoch 31/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1227 - val_loss: 0.2165
# Epoch 32/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1231 - val_loss: 0.2138
# Epoch 33/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1221 - val_loss: 0.2116
# Epoch 34/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1209 - val_loss: 0.2184
# Epoch 35/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1204 - val_loss: 0.2145
# Epoch 36/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1191 - val_loss: 0.2122
# Epoch 37/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1188 - val_loss: 0.2125
# Epoch 38/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1180 - val_loss: 0.2112
# Epoch 39/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1173 - val_loss: 0.2147
# Epoch 40/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1175 - val_loss: 0.2133
# Epoch 41/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1161 - val_loss: 0.2138
# Epoch 42/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1159 - val_loss: 0.2121
# Epoch 43/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1166 - val_loss: 0.2078
# Epoch 44/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1133 - val_loss: 0.2104
# Epoch 45/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1147 - val_loss: 0.2068
# Epoch 46/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1147 - val_loss: 0.2085
# Epoch 47/100
# 12/12 [==============================] - 0s 19ms/step - loss: 0.1130 - val_loss: 0.2091
# Epoch 48/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1132 - val_loss: 0.2063
# Epoch 49/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1125 - val_loss: 0.2071
# Epoch 50/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1125 - val_loss: 0.2075
# Epoch 51/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1118 - val_loss: 0.2053
# Epoch 52/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1119 - val_loss: 0.2073
# Epoch 53/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1119 - val_loss: 0.2054
# Epoch 54/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1103 - val_loss: 0.2093
# Epoch 55/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1111 - val_loss: 0.2040
# Epoch 56/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1103 - val_loss: 0.2069
# Epoch 57/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1100 - val_loss: 0.2114
# Epoch 58/100
# 12/12 [==============================] - 0s 19ms/step - loss: 0.1101 - val_loss: 0.2067
# Epoch 59/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1094 - val_loss: 0.2040
# Epoch 60/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1089 - val_loss: 0.2035
# Epoch 61/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1099 - val_loss: 0.2032
# Epoch 62/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1081 - val_loss: 0.2034
# Epoch 63/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1081 - val_loss: 0.2048
# Epoch 64/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1078 - val_loss: 0.2082
# Epoch 65/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1089 - val_loss: 0.2065
# Epoch 66/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1075 - val_loss: 0.2021
# Epoch 67/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1070 - val_loss: 0.2014
# Epoch 68/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1083 - val_loss: 0.2001
# Epoch 69/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1065 - val_loss: 0.2032
# Epoch 70/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1068 - val_loss: 0.2033
# Epoch 71/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1067 - val_loss: 0.2018
# Epoch 72/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1071 - val_loss: 0.2014
# Epoch 73/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1059 - val_loss: 0.2022
# Epoch 74/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1060 - val_loss: 0.2035
# Epoch 75/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1053 - val_loss: 0.2004
# Epoch 76/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1061 - val_loss: 0.2017
# Epoch 77/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1053 - val_loss: 0.2010
# Epoch 78/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1056 - val_loss: 0.2003
# Epoch 79/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1044 - val_loss: 0.2020
# Epoch 80/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1050 - val_loss: 0.1996
# Epoch 81/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1053 - val_loss: 0.1974
# Epoch 82/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1041 - val_loss: 0.2035
# Epoch 83/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1046 - val_loss: 0.1996
# Epoch 84/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1037 - val_loss: 0.2043
# Epoch 85/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1043 - val_loss: 0.1993
# Epoch 86/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1040 - val_loss: 0.1988
# Epoch 87/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1034 - val_loss: 0.2000
# Epoch 88/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1041 - val_loss: 0.1988
# Epoch 89/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1029 - val_loss: 0.2025
# Epoch 90/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1034 - val_loss: 0.2009
# Epoch 91/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1033 - val_loss: 0.1995
# Epoch 92/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1031 - val_loss: 0.1995
# Epoch 93/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1030 - val_loss: 0.2009
# Epoch 94/100
# 12/12 [==============================] - 0s 20ms/step - loss: 0.1027 - val_loss: 0.2002
# Epoch 95/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1024 - val_loss: 0.2008
# Epoch 96/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1025 - val_loss: 0.1974
# Epoch 97/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1028 - val_loss: 0.1977
# Epoch 98/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1019 - val_loss: 0.2004
# Epoch 99/100
# 12/12 [==============================] - 0s 20ms/step - loss: 0.1028 - val_loss: 0.1983
# Epoch 100/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1017 - val_loss: 0.1986

# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()

# %%
show_reconstructions(variational_ae, test_data, 30)
plt.show()

# %%
show_reconstructions(variational_ae, normal_test_data, 30)
plt.show()

# %%
show_reconstructions(variational_ae, abnormal_test_data, 30)
plt.show()

# %%
reconstructions_nl_test = variational_ae.predict(normal_test_data)

# %%
plt.figure(figsize=(25,7))
plt.plot(normal_test_data[0].ravel(), 'r')
plt.plot(reconstructions_nl_test[0].ravel(), 'g')
plt.fill_between(np.arange(28*28), reconstructions_nl_test[0].ravel(), normal_test_data[0].ravel(), color='blue')
plt.legend(labels=["Input", "Reconstruction", "Error"])
plt.show()

# %%
reconstructions_abn_test = variational_ae.predict(abnormal_test_data)

# %%
plt.figure(figsize=(1,1))
plt.imshow(abnormal_test_data[0], cmap="binary")
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(1,1))
plt.imshow(reconstructions_abn_test[0], cmap="binary")
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(25,7))
plt.plot(abnormal_test_data[0].ravel(), 'r')
plt.plot(reconstructions_abn_test[0].ravel(), 'g')
plt.fill_between(np.arange(28*28), reconstructions_abn_test[0].ravel(), normal_test_data[0].ravel(), color='blue')
plt.legend(labels=["Input", "Reconstruction", "Error"])
plt.show()

# %%
reconstructions_nl_data = variational_ae.predict(normal_data)
train_loss = tf.keras.losses.mae(reconstructions_nl_data.reshape(-1, 784), normal_data.reshape(-1, 784))
plt.hist(train_loss[None,:], bins=50)
plt.xlabel("Train loss")
plt.ylabel("No of examples")
plt.show()

# %%
threshold1 = np.mean(train_loss) + np.std(train_loss)
print("Threshold1: ", threshold1)
# Out:
# Threshold1:  0.051088206

# %%
abn_test_loss = tf.keras.losses.mae(reconstructions_abn_test.reshape(-1,784), abnormal_test_data.reshape(-1,784))

plt.hist(abn_test_loss[None, :], bins=50)
plt.xlabel("Abnormal Test loss")
plt.ylabel("No of examples")
plt.show()

# %%
threshold2 = np.mean(abn_test_loss) - np.std(abn_test_loss)
print("Threshold2: ", threshold2)
# Out:
# Threshold2:  0.08931275

# %%
np.mean(abn_test_loss) , np.std(abn_test_loss)
# Out:
# (0.1123558, 0.023043053)

# %%
def predict(model, data, threshold):
  reconstructions = model.predict(data)
  loss = tf.keras.losses.mae(reconstructions.reshape(-1, 784), data.reshape(-1, 784))
  return tf.math.less(loss, threshold)

def print_stats(predictions, labels):
  cf = confusion_matrix(labels, predictions)
  print("Confusion Matrix: \n prediction: F      T ")
  print("             {}   {}".format(preds[preds == False].shape[0], preds[preds == True].shape[0]))
  print(" label: F   [[{}   {}]    {}".format(cf[0,0], cf[0,1], test_labels_T_F[test_labels_T_F == False].shape[0]))
  print("        T    [{}   {}]]   {}".format(cf[1,0], cf[1,1], test_labels_T_F[test_labels_T_F == True].shape[0]))
  print("Accuracy = {}".format(accuracy_score(labels, predictions)))
  print("Precision = {}".format(precision_score(labels, predictions)))
  print("Recall = {}".format(recall_score(labels, predictions)))

# %%
preds = predict(variational_ae, test_data, (threshold1 + threshold2)/2)
print_stats(preds, test_labels_T_F)
# Out:
# Confusion Matrix:
#  prediction: F      T
#              980   976
#  label: F   [[959   15]    974
#         T    [21   961]]   982
# Accuracy = 0.9815950920245399
# Precision = 0.9846311475409836
# Recall = 0.9786150712830958

# %%
print(confusion_matrix(test_labels_T_F, preds))
# Out:
# [[959  15]
#  [ 21 961]]

# %%
reconstructions_test_data = variational_ae.predict(test_data)
test_loss = tf.keras.losses.mae(reconstructions_test_data.reshape(-1,784), test_data.reshape(-1,784))

plt.hist(test_loss[None, :], bins=50)
plt.xlabel("Test loss")
plt.ylabel("No of examples")
plt.show()

# %%
def plot_multiple_images(images, n_cols=None):
    n_cols = n_cols or len(images)
    n_rows = (len(images) - 1) // n_cols + 1
    if images.shape[-1] == 1:
        images = np.squeeze(images, axis=-1)
    plt.figure(figsize=(n_cols, n_rows))
    for index, image in enumerate(images):
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(image, cmap="binary")
        plt.axis("off")

# %%
codings = tf.random.normal(shape=[12, codings_size])
images = variational_decoder(codings).numpy()
plot_multiple_images(images, 4)
# save_fig("vae_generated_images_plot", tight_layout=False)

# %%
codings_grid = tf.reshape(codings, [1, 3, 4, codings_size])
larger_grid = tf.image.resize(codings_grid, size=[5, 7])
interpolated_codings = tf.reshape(larger_grid, [-1, codings_size])
images = variational_decoder(interpolated_codings).numpy()

plt.figure(figsize=(7, 5))
for index, image in enumerate(images):
    plt.subplot(5, 7, index + 1)
    if index%7%2==0 and index//7%2==0:
        plt.gca().get_xaxis().set_visible(False)
        plt.gca().get_yaxis().set_visible(False)
    else:
        plt.axis("off")
    plt.imshow(image, cmap="binary")
# save_fig("semantic_interpolation_plot", tight_layout=False)
